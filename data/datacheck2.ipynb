# %% [markdown]
# # Convert GeoJson File (10T Resample)

# %%
import json

def load_geojson(filename):
    geojson_data_path = '../server/testdata/' + filename + '.geojson'
    try:
        with open(geojson_data_path, 'r') as file:
            data = json.load(file)
        print("GeoJSON data loaded successfully.")
        return data
    except Exception as e:
        raise ValueError(f"An error occurred while loading the GeoJSON data: {e}")

# %%
import geopandas as gpd

def load_geojson_gpd(filename):
    # Path to the GeoJSON file
    geojson_data_path = '../server/testdata/' + filename + '.geojson'

    # Read the GeoJSON file
    try:
        gdf_geojson = gpd.read_file(geojson_data_path)
        print("GeoJSON data loaded successfully.")
        return gdf_geojson
    
    except Exception as e:
        print(f"An error occurred while loading the GeoJSON data: {e}")

# %%
myjsonfile = load_geojson('passenger_data_resample10T')
myjsonfile
# Out:
# GeoJSON data loaded successfully.
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-12T01:30:00',
#     'SEQUENCE_ID': 1.0,
#     'LA': 31.468265,
#     'LO': 126.542485,
#     'SOG': 10.7,
#     'COG': 96.8,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 148.67964567511444,
#     'sea_lv': 182.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:00:00',
#     'SEQUENCE_ID': 2.0,
#     'LA': 31.409738333333333,
#     'LO': 126.31339666666666,
#     'SOG': 5.3,
#     'COG': 60.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 133.91085080078506,
#     'sea_lv': 228.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:10:00',
#     'SEQUENCE_ID': 2.0,
#     'LA': 31.432781666666667,
#     'LO': 126.316425,
#     'SOG': 9.4,
#     'COG': 357.7,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 132.64646543076776,
#     'sea_lv': 227.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:20:00',
#     'SEQUENCE_ID': 2.0,
#     'LA': 31.451929166666666,
#     'LO': 126.31197805555556,
#     'SOG': 6.216666666666667,
#     'COG': 338.8333333333333,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 131.08087610357373,
#     'sea_lv': 225.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:30:00',
#     'SEQUENCE_ID': 3.0,
#     'LA': 31.560966666666666,
#     'LO': 126.59531666666666,
#     'SOG': 9.0,
#     'COG': 106.1,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 148.42747481659651,
#     'sea_lv': 74.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:40:00',
#     'SEQUENCE_ID': 3.0,
#     'LA': 31.552406666666663,
#     'LO': 126.60876833333332,
#     'SOG': 9.5,
#     'COG': 115.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 149.98512934808622,
#     'sea_lv': 72.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:50:00',
#     'SEQUENCE_ID': 3.0,
#     'LA': 31.552406666666663,
#     'LO': 126.60876833333332,
#     'SOG': 9.5,
#     'COG': 115.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 149.98512934808622,
#     'sea_lv': 71.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T15:00:00',
#     'SEQUENCE_ID': 3.0,
#     'LA': 31.519395,
#     'LO': 126.6716,
#     'SOG': 9.85,
#     'COG': 134.3,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 156.93703609077133,
#     'sea_lv': 69.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T15:10:00',
#     'SEQUENCE_ID': 3.0,
#     'LA': 31.505153333333332,
#     'LO': 126.6907911111111,
#     'SOG': 5.666666666666667,
#     'COG': 134.33333333333334,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 159.2614297995469,
#     'sea_lv': 68.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-09-27T18:30:00',
#     'SEQUENCE_ID': 4.0,
#     'LA': 31.637795,
#     'LO': 124.26229666666669,
#     'SOG': 5.6,
#     'COG': 104.0,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 100.63611887482556,
#     'sea_lv': 69.0,
#     'port_name': '이어도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:30:00',
#     'SEQUENCE_ID': 1.0,
#     'LA': 33.957051666666665,
#     'LO': 124.00019333333331,
#     'SOG': 11.9,
#     'COG': 122.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 53.85561659584085,
#     'sea_lv': 165.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:40:00',
#     'SEQUENCE_ID': 1.0,
#     'LA': 33.9408,
#     'LO': 124.02894166666668,
#     'SOG': 11.8,
#     'COG': 124.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 51.15074865633891,
#     'sea_lv': 167.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:50:00',
#     'SEQUENCE_ID': 1.0,
#     'LA': 33.92131166666667,
#     'LO': 124.06248,
#     'SOG': 12.0,
#     'COG': 124.7,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist':
9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 96.23678872171189,
#     'sea_lv': 243.0,
#     'port_name': '홍도항'},
#    'geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T11:50:00',
#     'SEQUENCE_ID': 4.0,
#     'LA': 35.258755,
#     'LO': 124.42809333333332,
#     'SOG': 11.9,
#     'COG': 156.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 95.24139343861481,
#     'sea_lv': 242.0,
#     'port_name': '홍도항'},
#    'geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:00:00',
#     'SEQUENCE_ID': 4.0,
#     'LA': 35.229180416666665,
#     'LO': 124.4421175,
#     'SOG': 11.9,
#     'COG': 162.825,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 92.06578387601824,
#     'sea_lv': 238.0,
#     'port_name': '홍도항'},
#    'geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:10:00',
#     'SEQUENCE_ID': 4.0,
#     'LA': 35.19683722222222,
#     'LO': 124.4544438888889,
#     'SOG': 11.9,
#     'COG': 162.56666666666666,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 88.82772697441052,
#     'sea_lv': 233.0,
#     'port_name': '홍도항'},
#    'geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:20:00',
#     'SEQUENCE_ID': 4.0,
#     'LA': 35.164645,
#     'LO': 124.46624833333334,
#     'SOG': 11.8,
#     'COG': 166.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 85.67944640624489,
#     'sea_lv': 228.0,
#     'port_name': '홍도항'},
#    'geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:10:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.34619333333333,
#     'LO': 124.71108666666667,
#     'SOG': 13.4,
#     'COG': 165.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 47.39012061801938,
#     'sea_lv': 53.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:20:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.33958333333333,
#     'LO': 124.71313,
#     'SOG': 13.4,
#     'COG': 165.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 46.72630133151415,
#     'sea_lv': 53.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:30:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.30379,
#     'LO': 124.72438833333334,
#     'SOG': 13.3,
#     'COG': 165.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 43.19150646363553,
#     'sea_lv': 54.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:40:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.268301666666666,
#     'LO': 124.73602666666666,
#     'SOG': 13.1,
#     'COG': 164.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.812371810250504,
#     'sea_lv': 56.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:50:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.233285,
#     'LO': 124.747835,
#     'SOG': 13.1,
#     'COG': 164.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 36.63302014801019,
#     'sea_lv': 58.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:00:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.197985,
#     'LO': 124.759645,
#     'SOG': 13.4,
#     'COG': 164.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 33.612437602443826,
#     'sea_lv': 60.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:10:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.16244666666667,
#     'LO': 124.77128166666668,
#     'SOG': 13.1,
#     'COG': 164.2,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 30.804556997454903,
#     'sea_lv': 63.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:20:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.12789,
#     'LO': 124.78285166666667,
#     'SOG': 12.9,
#     'COG': 163.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 28.391695817742868,
#     'sea_lv': 67.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:30:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.09085666666667,
#     'LO': 124.79529166666669,
#     'SOG': 12.7,
#     'COG': 164.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 26.239397922360446,
#     'sea_lv': 71.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:40:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.05920611111111,
#     'LO': 124.80563722222223,
#     'SOG': 12.6,
#     'COG': 164.63333333333333,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 24.817837070009503,
#     'sea_lv': 76.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:50:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 34.02619166666666,
#     'LO': 124.81608888888888,
#     'SOG': 12.5,
#     'COG': 165.16666666666666,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 23.816735069020286,
#     'sea_lv': 81.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06
00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.36284333333333,
#     'LO': 125.04577333333332,
#     'SOG': 11.1,
#     'COG': 158.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 76.52687362171697,
#     'sea_lv': 210.0,
#     'port_name': '신안가거초'},
#    'geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T21:30:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.33382666666667,
#     'LO': 125.05909666666666,
#     'SOG': 10.9,
#     'COG': 159.0,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 79.81288674135727,
#     'sea_lv': 247.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T21:40:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.30609,
#     'LO': 125.07211833333334,
#     'SOG': 10.9,
#     'COG': 158.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 82.82179185784209,
#     'sea_lv': 251.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T21:50:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.277140555555555,
#     'LO': 125.08537555555556,
#     'SOG': 10.933333333333334,
#     'COG': 159.43333333333334,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 85.98695646683097,
#     'sea_lv': 254.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T22:00:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.24850611111111,
#     'LO': 125.09813611111112,
#     'SOG': 11.066666666666666,
#     'COG': 159.76666666666668,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 89.13868712987369,
#     'sea_lv': 257.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T22:10:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.21937666666667,
#     'LO': 125.11134388888888,
#     'SOG': 11.0,
#     'COG': 158.73333333333335,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 92.36254435586606,
#     'sea_lv': 260.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T22:20:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.19151611111111,
#     'LO': 125.12397666666666,
#     'SOG': 11.0,
#     'COG': 159.66666666666669,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 95.4615822814314,
#     'sea_lv': 262.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T22:30:00',
#     'SEQUENCE_ID': 5.0,
#     'LA': 33.16177111111111,
#     'LO': 125.13727555555555,
#     'SOG': 11.166666666666666,
#     'COG': 159.53333333333333,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 98.78511519042402,
#     'sea_lv': 263.0,
#     'port_name': '가거도'},
#    'geometry': {'type': 'Point', 'coordinates': [125.11667, 34.05]}},
# ...
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 128.89518556847815,
#     'sea_lv': 103.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T07:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 33.018115,
#     'LO': 128.1794966666667,
#     'SOG': 15.9,
#     'COG': 217.7,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 127.59283114235674,
#     'sea_lv': 106.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T07:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.98092333333334,
#     'LO': 128.14567666666667,
#     'SOG': 15.8,
#     'COG': 217.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 126.43677515831645,
#     'sea_lv': 109.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:00:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.9497,
#     'LO': 128.11280333333335,
#     'SOG': 15.9,
#     'COG': 227.9,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 125.25168954705607,
#     'sea_lv': 113.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:10:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.92259,
#     'LO': 128.07207833333334,
#     'SOG': 15.7,
#     'COG': 234.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 123.36256127020401,
#     'sea_lv': 116.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:20:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.896845,
#     'LO': 128.02902333333333,
#     'SOG': 15.6,
#     'COG': 234.7,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 121.37002423825261,
#     'sea_lv': 121.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:30:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.869591666666665,
#     'LO': 127.99089833333332,
#     'SOG': 14.8,
#     'COG': 211.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 120.02089820409503,
#     'sea_lv': 125.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.832271666666664,
#     'LO': 127.96776166666666,
#     'SOG': 15.0,
#     'COG': 207.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 120.62885858286634,
#     'sea_lv': 130.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.79562,
#     'LO': 127.94510833333334,
#     'SOG': 14.9,
#     'COG': 207.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 121.4019796742735,
#     'sea_lv': 134.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:00:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.759056666666666,
#     'LO': 127.91919666666666,
#     'SOG': 14.9,
#     'COG': 212.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 122.10251738188671,
#     'sea_lv': 139.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:10:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.72479333333333,
#     'LO': 127.89298,
#     'SOG': 14.9,
#     'COG': 212.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 122.78557204297799,
#     'sea_lv': 144.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:20:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.689346666666665,
#     'LO': 127.865555,
#     'SOG': 14.9,
#     'COG': 212.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 123.64099695573415,
#     'sea_lv': 149.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:30:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.65430166666667,
#     'LO': 127.84069333333332,
#     'SOG': 14.8,
#     'COG': 208.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 124.79839171571118,
#     'sea_lv': 154.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.61808666666666,
#     'LO': 127.81758,
#     'SOG': 14.9,
#     'COG': 213.2,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 126.31286177751282,
#     'sea_lv': 159.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.58250666666667,
#     'LO': 127.789505,
#     'SOG': 15.4,
#     'COG': 218.3,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 127.62142171806968,
#     'sea_lv': 164.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:00:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.54856,
#     'LO': 127.75490666666668,
#     'SOG': 15.5,
#     'COG': 225.7,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 128.57485240048732,
#     'sea_lv': 169.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:10:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.518355,
#     'LO': 127.719045,
#     'SOG': 15.4,
#     'COG': 225.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 129.30152357101397,
#     'sea_lv': 173.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:20:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.487856666666666,
#     'LO': 127.68359666666667,
#     'SOG': 15.4,
#     'COG': 221.3,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 130.24399146695222,
#     'sea_lv': 177.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:30:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.45554166666667,
#     'LO': 127.64923166666668,
#     'SOG': 15.3,
#     'COG': 222.3,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 131.57482824448022,
#     'sea_lv': 181.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.42387,
#     'LO': 127.61774166666666,
#     'SOG': 14.9,
#     'COG': 216.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 133.1346576084063,
#     'sea_lv': 185.0,
#     'port_name': '성산포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.38952833333333,
#     'LO': 127.58695666666668,
#     'SOG': 15.3,
#     'COG': 217.0,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 134.88608632653975,
#     'sea_lv': 227.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:00:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.35418855555555,
#     'LO': 127.556044,
#     'SOG': 15.586666666666668,
#     'COG': 216.44666666666666,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 135.64304948641407,
#     'sea_lv': 231.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:10:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.31926083333333,
#     'LO': 127.52550833333333,
#     'SOG': 15.85,
#     'COG': 216.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 136.5578305664541,
#     'sea_lv': 234.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:20:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.28476833333333,
#     'LO': 127.49544,
#     'SOG': 16.0,
#     'COG': 217.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 137.62478003978177,
#     'sea_lv': 237.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:30:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.247915,
#     'LO': 127.46344166666668,
#     'SOG': 16.1,
#     'COG': 216.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 138.94151372610614,
#     'sea_lv': 239.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.211845,
#     'LO': 127.43166833333332,
#     'SOG': 16.6,
#     'COG': 218.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 140.36952244815507,
#     'sea_lv': 241.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.175695,
#     'LO': 127.39788333333334,
#     'SOG': 16.5,
#     'COG': 218.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 141.85946329073244,
#     'sea_lv': 243.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:00:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.13858,
#     'LO': 127.36382666666668,
#     'SOG': 16.4,
#     'COG': 217.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 143.592512783737,
#     'sea_lv': 244.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:10:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.10174333333333,
#     'LO': 127.33072,
#     'SOG': 16.6,
#     'COG': 217.2,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 145.50832745351488,
#     'sea_lv': 244.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:20:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.065981666666666,
#     'LO': 127.29867833333331,
#     'SOG': 16.6,
#     'COG': 217.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 147.51877773750383,
#     'sea_lv': 244.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:30:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 32.02855666666667,
#     'LO': 127.26539333333334,
#     'SOG': 16.7,
#     'COG': 216.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 149.78045915588555,
#     'sea_lv': 243.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.991156666666665,
#     'LO': 127.232695,
#     'SOG': 16.7,
#     'COG': 216.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 152.20563325038643,
#     'sea_lv': 242.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.953101666666665,
#     'LO': 127.19923333333334,
#     'SOG': 16.8,
#     'COG': 219.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 154.80310363040164,
#     'sea_lv': 240.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:00:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.916856904761904,
#     'LO': 127.16465333333335,
#     'SOG': 16.7,
#     'COG': 219.17142857142855,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 157.30693176017033,
#     'sea_lv': 238.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:10:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.881169444444446,
#     'LO': 127.13066166666665,
#     'SOG': 16.8,
#     'COG': 219.03333333333333,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 159.8982950764987,
#     'sea_lv': 235.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:20:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.84383453125,
#     'LO': 127.09582348958332,
#     'SOG': 16.828125,
#     'COG': 218.746875,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 162.7558638835291,
#     'sea_lv': 232.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:30:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.806284010416665,
#     'LO': 127.06084588541667,
#     'SOG': 16.859375,
#     'COG': 218.465625,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 165.7509005008979,
#     'sea_lv': 228.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:40:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.76873348958333,
#     'LO': 127.02586828125,
#     'SOG': 16.890625,
#     'COG': 218.184375,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 168.8590167656061,
#     'sea_lv': 224.0,
#     'port_name': '서귀포'},
#    'geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:50:00',
#     'SEQUENCE_ID': 8.0,
#     'LA': 31.731724047619043,
#     'LO': 126.99159285714286,
#     'SOG': 16.9,
#     'COG': 218.1142857142857,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 171.75074952829988,
#     'sea_lv': 216.0,
#     'port_name': '도농탄'},
#    'geometry': {'type': 'Point', 'coordinates': [126.26667, 33.15]}},
#   ...]}

# %%
mygdffile = load_geojson_gpd('passenger_data_resample10T')
mygdffile
# Out:
# GeoJSON data loaded successfully.
#            SHIP_ID           RECPTN_DT  SEQUENCE_ID         LA          LO  \
# 0        123456788 2022-08-12 01:30:00          1.0  31.468265  126.542485
# 1        123456788 2022-08-24 22:00:00          2.0  31.409738  126.313397
# 2        123456788 2022-08-24 22:10:00          2.0  31.432782  126.316425
# 3        123456788 2022-08-24 22:20:00          2.0  31.451929  126.311978
# 4        123456788 2022-08-25 14:30:00          3.0  31.560967  126.595317
# ...            ...                 ...          ...        ...         ...
# 1626311  667002108 2022-11-22 19:40:00         20.0  38.159287  131.734440
# 1626312  667002108 2022-11-22 19:50:00         20.0  38.181743  131.750356
# 1626313  667002108 2022-11-22 20:00:00         20.0  38.202060  131.764880
# 1626314  667002108 2022-11-22 20:10:00         20.0  38.223666  131.779747
# 1626315  667002108 2022-11-22 20:20:00         20.0  38.245223  131.794027
#
#                SOG         COG       TYPE     TON        dist  sea_lv  \
# 0        10.700000   96.800000  passenger    11.0  148.679646   182.0
# 1         5.300000   60.500000  passenger    11.0  133.910851   228.0
# 2         9.400000  357.700000  passenger    11.0  132.646465   227.0
# 3         6.216667  338.833333  passenger    11.0  131.080876   225.0
# 4         9.000000  106.100000  passenger    11.0  148.427475    74.0
# ...            ...         ...        ...     ...         ...     ...
# 1626311   8.700000   27.600000  passenger  7653.0   97.656542     9.0
# 1626312   8.266667   31.366667  passenger  7653.0  100.390809    10.0
# 1626313   8.800000   29.300000  passenger  7653.0  102.877772    10.0
# 1626314   8.800000   29.166667  passenger  7653.0  105.491824    11.0
# 1626315   9.100000   27.800000  passenger  7653.0  108.071509    11.0
#
#         port_name                    geometry
# 0             이어도  POINT (125.16667 32.11667)
# 1             이어도  POINT (125.16667 32.11667)
# 2             이어도  POINT (125.16667 32.11667)
# 3             이어도  POINT (125.16667 32.11667)
# 4             이어도  POINT (125.16667 32.11667)
# ...           ...                         ...
# 1626311       쌍정초  POINT (130.93333 37.55000)
# 1626312       쌍정초  POINT (130.93333 37.55000)
# 1626313       쌍정초  POINT (130.93333 37.55000)
# 1626314       쌍정초  POINT (130.93333 37.55000)
# 1626315       쌍정초  POINT (130.93333 37.55000)
#
# [1626316 rows x 13 columns]

# %%
import json

def transform_geojson(input_filename, output_filename):
    geojson_data_path = '../server/testdata/' + input_filename + '.geojson'
    
    try:
        # Load the existing GeoJSON data
        with open(geojson_data_path, 'r') as file:
            data = json.load(file)
        print("GeoJSON data loaded successfully.")
        
        # Transform the data
        transformed_features = []
        for feature in data['features']:
            # Extract properties
            properties = feature['properties']
            
            # Create new geometry for the ship's coordinates
            ship_geometry = {
                'type': 'Point',
                'coordinates': [properties['LO'], properties['LA']]
            }
            
            # Add the port coordinates separately
            port_geometry = feature['geometry']  # This is the port's coordinates
            
            # Construct the new feature
            new_feature = {
                'type': 'Feature',
                'properties': {
                    'SHIP_ID': properties['SHIP_ID'],
                    'RECPTN_DT': properties['RECPTN_DT'],
                    'SEQUENCE_ID': int(properties['SEQUENCE_ID']),  # Convert SEQUENCE_ID to int
                    'SOG': properties['SOG'],
                    'COG': properties['COG'],
                    'TYPE': properties['TYPE'],
                    'TON': properties['TON'],
                    'dist': properties['dist'],
                    'sea_lv': properties['sea_lv'],
                    'port_name': properties['port_name'],
                    'port_geometry': port_geometry
                },
                'geometry': ship_geometry
            }
            
            # Add the transformed feature to the list
            transformed_features.append(new_feature)
        
        # Construct the new GeoJSON structure
        transformed_geojson = {
            'type': 'FeatureCollection',
            'features': transformed_features
        }
        
        # Save the transformed GeoJSON data to a new file
        output_path = '../server/testdata/' + output_filename + '.geojson'
        with open(output_path, 'w') as outfile:
            json.dump(transformed_geojson, outfile, indent=4)
        print(f"Transformed GeoJSON data saved successfully to {output_filename}.geojson")
        
    except Exception as e:
        print(f"An error occurred while processing the GeoJSON data: {e}")

# %%
# Example usage
transform_geojson('passenger_data_resample10T', 'passenger_data_resample10T_ver02')
# Out:
# GeoJSON data loaded successfully.
# Transformed GeoJSON data saved successfully to passenger_data_resample10T_ver02.geojson

# %%
myjsonfile2 = load_geojson('passenger_data_resample10T_ver02')
myjsonfile2
# Out:
# GeoJSON data loaded successfully.
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-12T01:30:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 10.7,
#     'COG': 96.8,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 148.67964567511444,
#     'sea_lv': 182.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point', 'coordinates': [126.542485, 31.468265]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:00:00',
#     'SEQUENCE_ID': 2,
#     'SOG': 5.3,
#     'COG': 60.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 133.91085080078506,
#     'sea_lv': 228.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.31339666666666, 31.409738333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:10:00',
#     'SEQUENCE_ID': 2,
#     'SOG': 9.4,
#     'COG': 357.7,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 132.64646543076776,
#     'sea_lv': 227.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.316425, 31.432781666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:20:00',
#     'SEQUENCE_ID': 2,
#     'SOG': 6.216666666666667,
#     'COG': 338.8333333333333,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 131.08087610357373,
#     'sea_lv': 225.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.31197805555556, 31.451929166666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:30:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 9.0,
#     'COG': 106.1,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 148.42747481659651,
#     'sea_lv': 74.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.59531666666666, 31.560966666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:40:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 9.5,
#     'COG': 115.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 149.98512934808622,
#     'sea_lv': 72.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.60876833333332, 31.552406666666663]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:50:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 9.5,
#     'COG': 115.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 149.98512934808622,
#     'sea_lv': 71.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.60876833333332, 31.552406666666663]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T15:00:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 9.85,
#     'COG': 134.3,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 156.93703609077133,
#     'sea_lv': 69.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point', 'coordinates': [126.6716, 31.519395]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T15:10:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 5.666666666666667,
#     'COG': 134.33333333333334,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 159.2614297995469,
#     'sea_lv': 68.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.6907911111111, 31.505153333333332]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-09-27T18:30:00',
#     'SEQUENCE_ID': 4,
#     'SOG': 5.6,
#     'COG': 104.0,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 100.63611887482556,
#     'sea_lv': 69.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.26229666666669, 31.637795]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:30:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 11.9,
#     'COG': 122.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 53.85561659584085,
#     'sea_lv': 165.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.00019333333331, 33.957051666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:40:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 11.8,
#     'COG': 124.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 51.15074865633891,
#     'sea_lv': 167.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.02894166666668, 33.9408]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:50:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 12.0,
#     'COG': 124.7,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 48.07407419897596,
#     'sea_lv': 169.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.06248, 33.92131166666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:00:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 13.0,
#     'COG': 123.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 45.081744331868805,
#     'sea_lv': 171.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.09624833333334, 33.901783333333334]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:10:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 13.6,
#     'COG': 128.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 42.18943879060048,
#     'sea_lv': 172.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.130805, 33.879448333333336]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:20:00',
#     'SEQUENCE_ID': 1,
#     'SOG': 14.0,
#     'COG': 128.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.38287030787185,
#     'sea_lv': 173.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124
0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.15482833333331, 31.900446666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T05:40:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 10.9,
#     'COG': 148.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 26.91407086969938,
#     'sea_lv': 190.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.17468166666669, 31.874721666666662]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T05:50:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 11.1,
#     'COG': 149.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 29.9308828590537,
#     'sea_lv': 189.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.19299666666667, 31.848423333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:00:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 11.1,
#     'COG': 147.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 33.03876495912978,
#     'sea_lv': 187.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.21174666666668, 31.822016666666663]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:10:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 11.2,
#     'COG': 145.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 36.21609973518376,
#     'sea_lv': 184.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.23127333333332, 31.795616666666668]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:20:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 11.3,
#     'COG': 144.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.39672328045806,
#     'sea_lv': 182.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.25184833333331, 31.769818333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:30:00',
#     'SEQUENCE_ID': 3,
#     'SOG': 11.5,
#     'COG': 145.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 42.82195102155247,
#     'sea_lv': 180.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.27397666666668, 31.742486666666668]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T11:40:00',
#     'SEQUENCE_ID': 4,
#     'SOG': 11.9,
#     'COG': 156.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 96.23678872171189,
#     'sea_lv': 243.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.423385, 35.267695]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T11:50:00',
#     'SEQUENCE_ID': 4,
#     'SOG': 11.9,
#     'COG': 156.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 95.24139343861481,
#     'sea_lv': 242.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.42809333333332, 35.258755]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:00:00',
#     'SEQUENCE_ID': 4,
#     'SOG': 11.9,
#     'COG': 162.825,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 92.06578387601824,
#     'sea_lv': 238.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.4421175, 35.229180416666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:10:00',
#     'SEQUENCE_ID': 4,
#     'SOG': 11.9,
#     'COG': 162.56666666666666,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 88.82772697441052,
#     'sea_lv': 233.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.4544438888889, 35.19683722222222]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:20:00',
#     'SEQUENCE_ID': 4,
#     'SOG': 11.8,
#     'COG': 166.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 85.67944640624489,
#     'sea_lv': 228.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.46624833333334, 35.164645]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:10:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.4,
#     'COG': 165.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 47.39012061801938,
#     'sea_lv': 53.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.71108666666667, 34.34619333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:20:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.4,
#     'COG': 165.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 46.72630133151415,
#     'sea_lv': 53.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.71313, 34.33958333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:30:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.3,
#     'COG': 165.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 43.19150646363553,
#     'sea_lv': 54.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.72438833333334, 34.30379]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:40:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.1,
#     'COG': 164.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.812371810250504,
#     'sea_lv': 56.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.73602666666666, 34.268301666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:50:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.1,
#     'COG': 164.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 36.63302014801019,
#     'sea_lv': 58.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.747835, 34.233285]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:00:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.4,
#     'COG': 164.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 33.612437602443826,
#     'sea_lv': 60.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.759645, 34.197985]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:10:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 13.1,
#     'COG': 164.2,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 30.804556997454903,
#     'sea_lv': 63.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.77128166666668, 34.16244666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:20:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 12.9,
#     'COG': 163.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 28.391695817742868,
#     'sea_lv': 67.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.78285166666667, 34.12789]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:30:00',
#     'SEQUENCE_ID': 5,
#     'SOG': 12.7,
#     'COG': 164.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 26.239397922360446,
#     'sea_lv': 71.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124
0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.232695, 31.991156666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:50:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.8,
#     'COG': 219.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 154.80310363040164,
#     'sea_lv': 240.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.19923333333334, 31.953101666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:00:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.7,
#     'COG': 219.17142857142855,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 157.30693176017033,
#     'sea_lv': 238.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.16465333333335, 31.916856904761904]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:10:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.8,
#     'COG': 219.03333333333333,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 159.8982950764987,
#     'sea_lv': 235.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.13066166666665, 31.881169444444446]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:20:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.828125,
#     'COG': 218.746875,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 162.7558638835291,
#     'sea_lv': 232.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.09582348958332, 31.84383453125]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:30:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.859375,
#     'COG': 218.465625,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 165.7509005008979,
#     'sea_lv': 228.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.06084588541667, 31.806284010416665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:40:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.890625,
#     'COG': 218.184375,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 168.8590167656061,
#     'sea_lv': 224.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.02586828125, 31.76873348958333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:50:00',
#     'SEQUENCE_ID': 8,
#     'SOG': 16.9,
#     'COG': 218.1142857142857,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 171.75074952829988,
#     'sea_lv': 216.0,
#     'port_name': '도농탄',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.26667, 33.15]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.99159285714286, 31.731724047619043]}},
#   ...]}

# %%
mygdffile2 = load_geojson_gpd('passenger_data_resample10T_ver02')
mygdffile2
# Out:
# GeoJSON data loaded successfully.
#            SHIP_ID           RECPTN_DT  SEQUENCE_ID        SOG         COG  \
# 0        123456788 2022-08-12 01:30:00            1  10.700000   96.800000
# 1        123456788 2022-08-24 22:00:00            2   5.300000   60.500000
# 2        123456788 2022-08-24 22:10:00            2   9.400000  357.700000
# 3        123456788 2022-08-24 22:20:00            2   6.216667  338.833333
# 4        123456788 2022-08-25 14:30:00            3   9.000000  106.100000
# ...            ...                 ...          ...        ...         ...
# 1626311  667002108 2022-11-22 19:40:00           20   8.700000   27.600000
# 1626312  667002108 2022-11-22 19:50:00           20   8.266667   31.366667
# 1626313  667002108 2022-11-22 20:00:00           20   8.800000   29.300000
# 1626314  667002108 2022-11-22 20:10:00           20   8.800000   29.166667
# 1626315  667002108 2022-11-22 20:20:00           20   9.100000   27.800000
#
#               TYPE     TON        dist  sea_lv port_name  \
# 0        passenger    11.0  148.679646   182.0       이어도
# 1        passenger    11.0  133.910851   228.0       이어도
# 2        passenger    11.0  132.646465   227.0       이어도
# 3        passenger    11.0  131.080876   225.0       이어도
# 4        passenger    11.0  148.427475    74.0       이어도
# ...            ...     ...         ...     ...       ...
# 1626311  passenger  7653.0   97.656542     9.0       쌍정초
# 1626312  passenger  7653.0  100.390809    10.0       쌍정초
# 1626313  passenger  7653.0  102.877772    10.0       쌍정초
# 1626314  passenger  7653.0  105.491824    11.0       쌍정초
# 1626315  passenger  7653.0  108.071509    11.0       쌍정초
#
#                                              port_geometry  \
# 0        {'type': 'Point', 'coordinates': [125.16667, 3...
# 1        {'type': 'Point', 'coordinates': [125.16667, 3...
# 2        {'type': 'Point', 'coordinates': [125.16667, 3...
# 3        {'type': 'Point', 'coordinates': [125.16667, 3...
# 4        {'type': 'Point', 'coordinates': [125.16667, 3...
# ...                                                    ...
# 1626311  {'type': 'Point', 'coordinates': [130.93333, 3...
# 1626312  {'type': 'Point', 'coordinates': [130.93333, 3...
# 1626313  {'type': 'Point', 'coordinates': [130.93333, 3...
# 1626314  {'type': 'Point', 'coordinates': [130.93333, 3...
# 1626315  {'type': 'Point', 'coordinates': [130.93333, 3...
#
#                            geometry
# 0        POINT (126.54248 31.46826)
# 1        POINT (126.31340 31.40974)
# 2        POINT (126.31642 31.43278)
# 3        POINT (126.31198 31.45193)
# 4        POINT (126.59532 31.56097)
# ...                             ...
# 1626311  POINT (131.73444 38.15929)
# 1626312  POINT (131.75036 38.18174)
# 1626313  POINT (131.76488 38.20206)
# 1626314  POINT (131.77975 38.22367)
# 1626315  POINT (131.79403 38.24522)
#
# [1626316 rows x 12 columns]

# %% [markdown]
# # Length Feature Mapping

# %%
import json
import pandas as pd
import numpy as np
from tqdm import tqdm

# Load the vessel_static.csv data
vessel_static = pd.read_csv('vessel_static.csv')

# Define the function to predict the length
def predict_length(ship_type, ton):
    # Filter the vessel_static data to match the ship type (case-insensitive)
    type_filtered = vessel_static[vessel_static['shiptype'].str.contains(ship_type, case=False, na=False)]
    
    if not type_filtered.empty:
        # Filter to match the TON
        ton_filtered = type_filtered[type_filtered['ton'] == ton]
        
        if not ton_filtered.empty:
            # If exact match, return the median length
            return ton_filtered['length'].median()
        else:
            # If no exact match, perform linear interpolation
            sorted_filtered = type_filtered.sort_values(by='ton')
            
            # Group by 'ton' and get the median length for interpolation
            grouped_median = sorted_filtered.groupby('ton')['length'].median().reset_index()
            
            # Find the closest values for interpolation
            lower_bound = grouped_median[grouped_median['ton'] <= ton].tail(1)
            upper_bound = grouped_median[grouped_median['ton'] >= ton].head(1)
            
            if not lower_bound.empty and not upper_bound.empty:
                if lower_bound['ton'].values[0] == upper_bound['ton'].values[0]:
                    return lower_bound['length'].values[0]
                else:
                    # Perform linear interpolation
                    x0, y0 = lower_bound['ton'].values[0], lower_bound['length'].values[0]
                    x1, y1 = upper_bound['ton'].values[0], upper_bound['length'].values[0]
                    return y0 + (ton - x0) * (y1 - y0) / (x1 - x0)
            elif not lower_bound.empty:
                return lower_bound['length'].values[0]
            elif not upper_bound.empty:
                return upper_bound['length'].values[0]
            else:
                return np.nan
    else:
        return np.nan

def predict_length_mapping(geojson_data, output_filename):
    # Add the LEN_PRED feature to each feature in the GeoJSON data with progress bar
    for feature in tqdm(geojson_data['features'], desc="Processing features"):
        properties = feature['properties']
        ship_type = properties['TYPE']
        ton = properties['TON']
        
        # Predict the length
        len_pred = predict_length(ship_type, ton)
        
        # Insert LEN_PRED into properties dictionary
        properties['LEN_PRED'] = len_pred

        # Reorder properties to insert LEN_PRED after TON
        ordered_properties = {k: properties[k] for k in list(properties)[:6]}
        ordered_properties['LEN_PRED'] = len_pred
        for k in list(properties)[6:]:
            ordered_properties[k] = properties[k]
        
        feature['properties'] = ordered_properties

    # Save the modified GeoJSON data to a new file
    output_geojson_path = '../server/testdata/' + output_filename + '.geojson'
    with open(output_geojson_path, 'w') as outfile:
        json.dump(geojson_data, outfile, indent=4)

    print(f"Transformed GeoJSON data with LEN_PRED saved successfully to {output_geojson_path}")

# %%
# Run the function with progress logging
predict_length_mapping(myjsonfile2, 'passenger_resample10T_ver03')
# Out:
# Processing features:   0%|          | 3256/1626316 [00:40<5:33:52, 81.02it/s]

# %%
myjsonfile3 = load_geojson('passenger_resample10T_ver03')
myjsonfile3

# %%
mygdffile3 = load_geojson_gpd('passenger_resample10T_ver03')
mygdffile3

# %% [markdown]
# ---

# %%
transform_geojson(myjsonfile)
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-12T01:30:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 10.7,
#     'COG': 96.8,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 148.67964567511444,
#     'sea_lv': 182.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point', 'coordinates': [126.542485, 31.468265]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:00:00',
#     'SEQUENCE_ID': 2.0,
#     'SOG': 5.3,
#     'COG': 60.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 133.91085080078506,
#     'sea_lv': 228.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.31339666666666, 31.409738333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:10:00',
#     'SEQUENCE_ID': 2.0,
#     'SOG': 9.4,
#     'COG': 357.7,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 132.64646543076776,
#     'sea_lv': 227.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.316425, 31.432781666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-24T22:20:00',
#     'SEQUENCE_ID': 2.0,
#     'SOG': 6.216666666666667,
#     'COG': 338.8333333333333,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 131.08087610357373,
#     'sea_lv': 225.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.31197805555556, 31.451929166666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:30:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 9.0,
#     'COG': 106.1,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 148.42747481659651,
#     'sea_lv': 74.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.59531666666666, 31.560966666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:40:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 9.5,
#     'COG': 115.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 149.98512934808622,
#     'sea_lv': 72.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.60876833333332, 31.552406666666663]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T14:50:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 9.5,
#     'COG': 115.5,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 149.98512934808622,
#     'sea_lv': 71.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.60876833333332, 31.552406666666663]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T15:00:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 9.85,
#     'COG': 134.3,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 156.93703609077133,
#     'sea_lv': 69.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point', 'coordinates': [126.6716, 31.519395]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-08-25T15:10:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 5.666666666666667,
#     'COG': 134.33333333333334,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 159.2614297995469,
#     'sea_lv': 68.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.6907911111111, 31.505153333333332]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '123456788',
#     'RECPTN_DT': '2022-09-27T18:30:00',
#     'SEQUENCE_ID': 4.0,
#     'SOG': 5.6,
#     'COG': 104.0,
#     'TYPE': 'passenger',
#     'TON': 11.0,
#     'dist': 100.63611887482556,
#     'sea_lv': 69.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.26229666666669, 31.637795]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:30:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 11.9,
#     'COG': 122.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 53.85561659584085,
#     'sea_lv': 165.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.00019333333331, 33.957051666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:40:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 11.8,
#     'COG': 124.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 51.15074865633891,
#     'sea_lv': 167.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.02894166666668, 33.9408]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T17:50:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 12.0,
#     'COG': 124.7,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 48.07407419897596,
#     'sea_lv': 169.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.06248, 33.92131166666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:00:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 13.0,
#     'COG': 123.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 45.081744331868805,
#     'sea_lv': 171.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.09624833333334, 33.901783333333334]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:10:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 13.6,
#     'COG': 128.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 42.18943879060048,
#     'sea_lv': 172.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.130805, 33.879448333333336]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:20:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 14.0,
#     'COG': 128.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.38287030787185,
#     'sea_lv': 173.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.16690833333334, 33.85610333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:30:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 13.6,
#     'COG': 163.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 38.19595000012654,
#     'sea_lv': 174.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.19091333333331, 33.824448333333336]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:40:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG': 12.2,
#     'COG': 162.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 38.54127936991851,
#     'sea_lv': 174.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.20361, 33.78940333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-07T18:50:00',
#     'SEQUENCE_ID': 1.0,
#     'SOG':
00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 11.1,
#     'COG': 147.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 33.03876495912978,
#     'sea_lv': 187.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.21174666666668, 31.822016666666663]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:10:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 11.2,
#     'COG': 145.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 36.21609973518376,
#     'sea_lv': 184.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.23127333333332, 31.795616666666668]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:20:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 11.3,
#     'COG': 144.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.39672328045806,
#     'sea_lv': 182.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.25184833333331, 31.769818333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-06-08T06:30:00',
#     'SEQUENCE_ID': 3.0,
#     'SOG': 11.5,
#     'COG': 145.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 42.82195102155247,
#     'sea_lv': 180.0,
#     'port_name': '이어도',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.16667, 32.11667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.27397666666668, 31.742486666666668]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T11:40:00',
#     'SEQUENCE_ID': 4.0,
#     'SOG': 11.9,
#     'COG': 156.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 96.23678872171189,
#     'sea_lv': 243.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.423385, 35.267695]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T11:50:00',
#     'SEQUENCE_ID': 4.0,
#     'SOG': 11.9,
#     'COG': 156.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 95.24139343861481,
#     'sea_lv': 242.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.42809333333332, 35.258755]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:00:00',
#     'SEQUENCE_ID': 4.0,
#     'SOG': 11.9,
#     'COG': 162.825,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 92.06578387601824,
#     'sea_lv': 238.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.4421175, 35.229180416666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:10:00',
#     'SEQUENCE_ID': 4.0,
#     'SOG': 11.9,
#     'COG': 162.56666666666666,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 88.82772697441052,
#     'sea_lv': 233.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.4544438888889, 35.19683722222222]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T12:20:00',
#     'SEQUENCE_ID': 4.0,
#     'SOG': 11.8,
#     'COG': 166.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 85.67944640624489,
#     'sea_lv': 228.0,
#     'port_name': '홍도항',
#     'port_geometry': {'type': 'Point', 'coordinates': [125.18333, 34.66667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.46624833333334, 35.164645]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:10:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.4,
#     'COG': 165.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 47.39012061801938,
#     'sea_lv': 53.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.71108666666667, 34.34619333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:20:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.4,
#     'COG': 165.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 46.72630133151415,
#     'sea_lv': 53.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.71313, 34.33958333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:30:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.3,
#     'COG': 165.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 43.19150646363553,
#     'sea_lv': 54.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.72438833333334, 34.30379]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:40:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.1,
#     'COG': 164.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 39.812371810250504,
#     'sea_lv': 56.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.73602666666666, 34.268301666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T16:50:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.1,
#     'COG': 164.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 36.63302014801019,
#     'sea_lv': 58.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.747835, 34.233285]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:00:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.4,
#     'COG': 164.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 33.612437602443826,
#     'sea_lv': 60.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.759645, 34.197985]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:10:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 13.1,
#     'COG': 164.2,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 30.804556997454903,
#     'sea_lv': 63.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.77128166666668, 34.16244666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:20:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.9,
#     'COG': 163.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 28.391695817742868,
#     'sea_lv': 67.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.78285166666667, 34.12789]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:30:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.7,
#     'COG': 164.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 26.239397922360446,
#     'sea_lv': 71.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.79529166666669, 34.09085666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:40:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.6,
#     'COG': 164.63333333333333,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 24.817837070009503,
#     'sea_lv': 76.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.80563722222223, 34.05920611111111]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T17:50:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.5,
#     'COG': 165.16666666666666,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 23.816735069020286,
#     'sea_lv': 81.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.81608888888888, 34.02619166666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T18:00:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.6,
#     'COG': 165.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 23.350264732702918,
#     'sea_lv': 86.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.82616833333331, 33.992756666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T18:10:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.6,
#     'COG': 165.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 23.47756270186191,
#     'sea_lv': 92.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.83601833333331, 33.958596666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T18:20:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.566666666666666,
#     'COG': 165.13333333333335,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 24.257925048841294,
#     'sea_lv': 98.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.84604555555556, 33.92463055555556]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T18:30:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.4,
#     'COG': 163.5,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 25.718952178241548,
#     'sea_lv': 104.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.85742333333332, 33.891423333333336]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T18:40:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.2,
#     'COG': 164.1,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 27.628820423889827,
#     'sea_lv': 110.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.86877333333334, 33.85849]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T18:50:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 12.0,
#     'COG': 164.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 29.99212478792812,
#     'sea_lv': 117.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.88024, 33.823835]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T19:00:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.8,
#     'COG': 165.3,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 32.24208333369327,
#     'sea_lv': 124.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.88958833333334, 33.79402833333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T19:10:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.7,
#     'COG': 164.2,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 34.83435793902111,
#     'sea_lv': 131.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.89958166666666, 33.762586666666664]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T19:20:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.9,
#     'COG': 164.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 37.81582390700344,
#     'sea_lv': 137.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.91045, 33.728831666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T19:30:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.8,
#     'COG': 164.6,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 40.564123849651054,
#     'sea_lv': 144.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.92000833333331, 33.69915833333334]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T19:40:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.6,
#     'COG': 165.4,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 43.55823124225855,
#     'sea_lv': 151.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.92994666666668, 33.667831666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T19:50:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.6,
#     'COG': 164.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 46.64760754797366,
#     'sea_lv': 158.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.940175, 33.636635]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T20:00:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.8,
#     'COG': 164.8,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 49.82010853666262,
#     'sea_lv': 165.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.95034333333334, 33.60521166666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T20:10:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.8,
#     'COG': 164.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 53.12947740986518,
#     'sea_lv': 171.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.96079333333333, 33.57304722222222]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T20:20:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.8,
#     'COG': 164.9,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 56.34558915154268,
#     'sea_lv': 177.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.97060166666668, 33.542105]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T20:30:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.7,
#     'COG': 163.0,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 59.70670294566896,
#     'sea_lv': 184.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point', 'coordinates': [124.981445, 33.51063]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T20:40:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.5,
#     'COG': 160.3,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 63.06266741456721,
#     'sea_lv': 189.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [124.993675, 33.48043166666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T20:50:00',
#     'SEQUENCE_ID': 5.0,
#     'SOG': 11.2,
#     'COG': 158.76666666666665,
#     'TYPE': 'passenger',
#     'TON': 44095.0,
#     'dist': 66.52731052675736,
#     'sea_lv': 195.0,
#     'port_name': '신안가거초',
#     'port_geometry': {'type': 'Point', 'coordinates': [124.58333, 33.93333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [125.00709833333333, 33.44996944444444]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '209682000',
#     'RECPTN_DT': '2022-10-06T21:00:00',
# ...
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:10:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.7,
#     'COG': 234.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 123.36256127020401,
#     'sea_lv': 116.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [128.07207833333334, 32.92259]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:20:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.6,
#     'COG': 234.7,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 121.37002423825261,
#     'sea_lv': 121.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [128.02902333333333, 32.896845]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:30:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.8,
#     'COG': 211.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 120.02089820409503,
#     'sea_lv': 125.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.99089833333332, 32.869591666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:40:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.0,
#     'COG': 207.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 120.62885858286634,
#     'sea_lv': 130.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.96776166666666, 32.832271666666664]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T08:50:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.9,
#     'COG': 207.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 121.4019796742735,
#     'sea_lv': 134.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.94510833333334, 32.79562]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:00:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.9,
#     'COG': 212.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 122.10251738188671,
#     'sea_lv': 139.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.91919666666666, 32.759056666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:10:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.9,
#     'COG': 212.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 122.78557204297799,
#     'sea_lv': 144.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.89298, 32.72479333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:20:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.9,
#     'COG': 212.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 123.64099695573415,
#     'sea_lv': 149.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.865555, 32.689346666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:30:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.8,
#     'COG': 208.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 124.79839171571118,
#     'sea_lv': 154.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.84069333333332, 32.65430166666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:40:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.9,
#     'COG': 213.2,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 126.31286177751282,
#     'sea_lv': 159.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.81758, 32.61808666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T09:50:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.4,
#     'COG': 218.3,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 127.62142171806968,
#     'sea_lv': 164.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.789505, 32.58250666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:00:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.5,
#     'COG': 225.7,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 128.57485240048732,
#     'sea_lv': 169.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.75490666666668, 32.54856]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:10:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.4,
#     'COG': 225.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 129.30152357101397,
#     'sea_lv': 173.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point', 'coordinates': [127.719045, 32.518355]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:20:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.4,
#     'COG': 221.3,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 130.24399146695222,
#     'sea_lv': 177.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.68359666666667, 32.487856666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:30:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.3,
#     'COG': 222.3,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 131.57482824448022,
#     'sea_lv': 181.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.64923166666668, 32.45554166666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:40:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 14.9,
#     'COG': 216.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 133.1346576084063,
#     'sea_lv': 185.0,
#     'port_name': '성산포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.91667, 33.46667]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.61774166666666, 32.42387]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T10:50:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.3,
#     'COG': 217.0,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 134.88608632653975,
#     'sea_lv': 227.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.58695666666668, 32.38952833333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:00:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.586666666666668,
#     'COG': 216.44666666666666,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 135.64304948641407,
#     'sea_lv': 231.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.556044, 32.35418855555555]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:10:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 15.85,
#     'COG': 216.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 136.5578305664541,
#     'sea_lv': 234.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.52550833333333, 32.31926083333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:20:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.0,
#     'COG': 217.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 137.62478003978177,
#     'sea_lv': 237.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.49544, 32.28476833333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:30:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.1,
#     'COG': 216.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 138.94151372610614,
#     'sea_lv': 239.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.46344166666668, 32.247915]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:40:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.6,
#     'COG': 218.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 140.36952244815507,
#     'sea_lv': 241.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.43166833333332, 32.211845]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T11:50:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.5,
#     'COG': 218.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 141.85946329073244,
#     'sea_lv': 243.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.39788333333334, 32.175695]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:00:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.4,
#     'COG': 217.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 143.592512783737,
#     'sea_lv': 244.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.36382666666668, 32.13858]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:10:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.6,
#     'COG': 217.2,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 145.50832745351488,
#     'sea_lv': 244.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.33072, 32.10174333333333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:20:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.6,
#     'COG': 217.1,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 147.51877773750383,
#     'sea_lv': 244.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.29867833333331, 32.065981666666666]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:30:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.7,
#     'COG': 216.8,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 149.78045915588555,
#     'sea_lv': 243.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.26539333333334, 32.02855666666667]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:40:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.7,
#     'COG': 216.5,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 152.20563325038643,
#     'sea_lv': 242.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.232695, 31.991156666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T12:50:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.8,
#     'COG': 219.6,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 154.80310363040164,
#     'sea_lv': 240.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.19923333333334, 31.953101666666665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:00:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.7,
#     'COG': 219.17142857142855,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 157.30693176017033,
#     'sea_lv': 238.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.16465333333335, 31.916856904761904]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:10:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.8,
#     'COG': 219.03333333333333,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 159.8982950764987,
#     'sea_lv': 235.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.13066166666665, 31.881169444444446]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:20:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.828125,
#     'COG': 218.746875,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 162.7558638835291,
#     'sea_lv': 232.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.09582348958332, 31.84383453125]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:30:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.859375,
#     'COG': 218.465625,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 165.7509005008979,
#     'sea_lv': 228.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.06084588541667, 31.806284010416665]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:40:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.890625,
#     'COG': 218.184375,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 168.8590167656061,
#     'sea_lv': 224.0,
#     'port_name': '서귀포',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.55, 33.23333]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [127.02586828125, 31.76873348958333]}},
#   {'type': 'Feature',
#    'properties': {'SHIP_ID': '229416000',
#     'RECPTN_DT': '2022-08-02T13:50:00',
#     'SEQUENCE_ID': 8.0,
#     'SOG': 16.9,
#     'COG': 218.1142857142857,
#     'TYPE': 'passenger',
#     'TON': 130200.0,
#     'dist': 171.75074952829988,
#     'sea_lv': 216.0,
#     'port_name': '도농탄',
#     'port_geometry': {'type': 'Point', 'coordinates': [126.26667, 33.15]}},
#    'geometry': {'type': 'Point',
#     'coordinates': [126.99159285714286, 31.731724047619043]}},
#   ...]}

# %%
import json

def transform_geojson(input_filename, output_filename):
    geojson_data_path = '../server/testdata/' + input_filename + '.geojson'
    
    try:
        # Load the existing GeoJSON data
        with open(geojson_data_path, 'r') as file:
            data = json.load(file)
        print("GeoJSON data loaded successfully.")
        
        # Transform the data
        transformed_features = []
        for feature in data['features']:
            # Extract properties
            properties = feature['properties']
            
            # Create new geometry for the ship's coordinates
            ship_geometry = {
                'type': 'Point',
                'coordinates': [properties['LO'], properties['LA']]
            }
            
            # Add the port coordinates separately
            port_geometry = feature['geometry']  # This is the port's coordinates
            
            # Construct the new feature
            new_feature = {
                'type': 'Feature',
                'properties': {
                    'SHIP_ID': properties['SHIP_ID'],
                    'RECPTN_DT': properties['RECPTN_DT'],
                    'SEQUENCE_ID': properties['SEQUENCE_ID'],
                    'SOG': properties['SOG'],
                    'COG': properties['COG'],
                    'TYPE': properties['TYPE'],
                    'TON': properties['TON'],
                    'dist': properties['dist'],
                    'sea_lv': properties['sea_lv'],
                    'port_name': properties['port_name'],
                    'port_geometry': port_geometry
                },
                'geometry': ship_geometry
            }
            
            # Add the transformed feature to the list
            transformed_features.append(new_feature)
        
        # Construct the new GeoJSON structure
        transformed_geojson = {
            'type': 'FeatureCollection',
            'features': transformed_features
        }
        
        # Save the transformed GeoJSON data to a new file
        output_path = '../server/testdata/' + output_filename + '.geojson'
        with open(output_path, 'w') as outfile:
            json.dump(transformed_geojson, outfile, indent=4)
        print(f"Transformed GeoJSON data saved successfully to {output_filename}.geojson")
        
    except Exception as e:
        print(f"An error occurred while processing the GeoJSON data: {e}")

# Example usage
transform_geojson('input_geojson_filename', 'output_geojson_filename')
